# %% [markdown]
# <a href="https://colab.research.google.com/github/9989275060/Adult.data/blob/main/dm1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
amazon_toy_sample = pd.read_csv("https://raw.githubusercontent.com/9989275060/Shinde_IT533/main/amazon_toy_sample_clean%5B1%5D.csv" , encoding="ISO-8859-1")

# %%
amazon_toy_sample
# Out:
#                                uniq_id  \
# 0     dafc6b4ba4b4a3e7b4ff83402a196ae8
# 1     ba85fb9368114fce646379ed12750a5f
# 2     14e24c29ba38c2717754baa2638f242a
# 4     7b72f597db5d74d35c4f91ef69708cf1
# 5     7b8a04095b5e4984c57fd45eb327feb1
# ...                                ...
# 6331  8020c8cd2b86bd2e793241dd321d8921
# 6332  ddd1807f90417adcdf4cd45841239e01
# 6333  1e897bf37e4e89aba7cc962f24913fd4
# 6334  4f705c302bdcf5d2b0c1df973d98f99f
# 6335  75d96583894e50412ba5c0161375fef5
#
#                                            product_name  \
# 0                                         Dinosaur Eggs
# 1      Neopets 4 Trading Card Fun Packs (2 Bonus Cards)
# 2             Latex Assorted Water Balloons, Pack of 40
# 4     4 Packs of Mini Colouring Pencils (4 pencils i...
# 5     100 Deep Red Rose Silk Petals Confetti - Weddi...
# ...                                                 ...
# 6331                       Parrot Bebop Drone 2 (White)
# ...

# %%
amazon_toy_sample.dtypes
# Out:
# uniq_id                                         object
# product_name                                    object
# manufacturer                                    object
# price                                          float64
# number_available_in_stock                        int64
# status                                          object
# number_of_reviews                                int64
# number_of_answered_questions                     int64
# average_review_rating_of_5                     float64
# amazon_category_and_sub_category                object
# customers_who_bought_this_item_also_bought      object
# description                                     object
# product_information                             object
# product_description                             object
# items_customers_buy_after_viewing_this_item     object
# customer_questions_and_answers                  object
# customer_reviews                                object
# dtype: object

# %%
new_amazon = amazon_toy_sample.dropna(inplace = True)
new_amazon

# %%
amazon_toy_sample.select_dtypes(include ='float64')
# Out:
#         price  average_review_rating_of_5
# 0        0.29                         4.0
# 1        0.38                         4.5
# 2        0.39                         4.5
# 4        0.60                         4.3
# 5        0.64                         4.1
# ...       ...                         ...
# 6331   439.95                         3.3
# 6332   447.99                         5.0
# 6333   719.95                         5.0
# 6334   995.11                         5.0
# 6335  2439.92                         4.0
#
# [6312 rows x 2 columns]

# %%
amazon_toy_sample.average_review_rating_of_5.std()
# Out:
# 0.42784568570093373

# %%
amazon_toy_sample.price.mean()
# Out:
# 20.246723700887213

# %%
amazon_toy_sample.groupby(['status','average_review_rating_of_5']).median()
# Out:
#                                           price  number_available_in_stock  \
# status      average_review_rating_of_5
# collectible 4.3                          19.990                        1.0
#             4.5                          15.950                        1.0
#             4.7                           3.990                        1.0
#             4.8                          39.990                        1.0
#             5.0                          15.990                        1.0
# new         0.0                          13.220                       11.5
#             2.3                          12.640                        6.0
#             3.0                           1.750                       14.0
#             3.3                         224.300                        6.5
#             3.5                          54.345                        7.5
#             3.6                           4.270                        6.0
# ...

# %%
amazon_toy_sample = amazon_toy_sample.astype({"price": float})

# %%
amazon_toy_sample.number_available_in_stock.describe(include='all')
# Out:
# count    6336.000000
# mean        8.735322
# std         9.117969
# min         1.000000
# 25%         3.000000
# 50%         5.000000
# 75%        11.000000
# max        92.000000
# Name: number_available_in_stock, dtype: float64

# %%
amazon_toy_sample.price
# Out:
# 0          0.29
# 1          0.38
# 2          0.39
# 3          0.50
# 4          0.60
#          ...
# 6331     439.95
# 6332     447.99
# 6333     719.95
# 6334     995.11
# 6335    2439.92
# Name: price, Length: 6336, dtype: float64

# %%
amazon_toy_sample.describe(include='all')
# Out:
#                                  uniq_id  \
# count                               6336
# unique                              6336
# top     dafc6b4ba4b4a3e7b4ff83402a196ae8
# freq                                   1
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
#
#                                              product_name    manufacturer  \
# count                                                6336            6336
# unique                                               6315            1763
# top     Zoo Animal Hand Sock Glove Finger Puppets Sack...  Oxford Diecast
# freq                                                    3             137
# mean                                                  NaN             NaN
# ...

# %%
amazon_toy_sample.price.describe(include='all')
# Out:
# count    6336.000000
# mean       20.213677
# std        46.288201
# min         0.290000
# 25%         5.832500
# 50%        11.280000
# 75%        20.500000
# max      2439.920000
# Name: price, dtype: float64

# %%
amazon_toy_sample.boxplot('price')

# %%
amazon_toy_sample.price.std()
# Out:
# 46.28820144871692

# %%
amazon_toy_sample.number_available_in_stock.std()
# Out:
# 9.117968720180638

# %%
amazon_toy_sample.average_review_rating_of_5.describe(include = 'all')
# Out:
# count    6336.000000
# mean        4.686222
# std         0.427656
# min         0.000000
# 25%         4.500000
# 50%         4.900000
# 75%         5.000000
# max         5.000000
# Name: average_review_rating_of_5, dtype: float64

# %%
amazon_toy_sample.average_review_rating_of_5.std()
# Out:
# 0.42765621863783376

# %%
point1 = np.array((amazon_toy_sample.price))
point2 = np.array((amazon_toy_sample.average_review_rating_of_5))
dist = np.linalg.norm(point1 - point2)
print("Euclidean distance between price and review_rating_of_5 is:", dist)
# Out:
# Euclidean distance between price and review_rating_of_5 is: 3885.7132155114073

# %%
point1 = np.array((amazon_toy_sample.price))
point2 = np.array((amazon_toy_sample.number_available_in_stock))
dist = np.linalg.norm(point1 - point2)
print("Euclidean distance between price and number_avaiable_in_stock is:", dist)
# Out:
# Euclidean distance between price and number_avaiable_in_stock is: 3877.045726219901

# %%
amazon_toy_sample.describe()
# Out:
#              price  number_available_in_stock  number_of_reviews  \
# count  6336.000000                6336.000000        6336.000000
# mean     20.213677                   8.735322          11.220013
# std      46.288201                   9.117969          39.292836
# min       0.290000                   1.000000           0.000000
# 25%       5.832500                   3.000000           1.000000
# 50%      11.280000                   5.000000           2.000000
# 75%      20.500000                  11.000000           8.000000
# max    2439.920000                  92.000000        1399.000000
#
#        number_of_answered_questions  average_review_rating_of_5
# count                   6336.000000                 6336.000000
# mean                       3.927715                    4.686222
# std                       13.417801                    0.427656
# min                        1.000000                    0.000000
# ...

# %%
amazon_toy_sample.dropna(inplace = True)
print(amazon_toy_sample)
# Out:
#                                uniq_id  \
# 0     dafc6b4ba4b4a3e7b4ff83402a196ae8
# 1     ba85fb9368114fce646379ed12750a5f
# 2     14e24c29ba38c2717754baa2638f242a
# 4     7b72f597db5d74d35c4f91ef69708cf1
# 5     7b8a04095b5e4984c57fd45eb327feb1
# ...                                ...
# 6331  8020c8cd2b86bd2e793241dd321d8921
# 6332  ddd1807f90417adcdf4cd45841239e01
# 6333  1e897bf37e4e89aba7cc962f24913fd4
# 6334  4f705c302bdcf5d2b0c1df973d98f99f
# 6335  75d96583894e50412ba5c0161375fef5
#
#                                            product_name  \
# 0                                         Dinosaur Eggs
# 1      Neopets 4 Trading Card Fun Packs (2 Bonus Cards)
# 2             Latex Assorted Water Balloons, Pack of 40
# 4     4 Packs of Mini Colouring Pencils (4 pencils i...
# 5     100 Deep Red Rose Silk Petals Confetti - Weddi...
# ...                                                 ...
# 6331                       Parrot Bebop Drone 2 (White)
# ...
